# %%
tup = (4, 5, 6)

# %%
a, b, fam = tup

# %%
fam
# Out:
# 6

# %%
tap = ((4, 5), (6, 7))

# %%
w, e = tap[1]

# %%
w
# Out:
# 6

# %%
a = (1, 2, 2, 2, 3, 4, 2)
a.index(4)
# Out:
# 5

# %%
seq = [7, 2, 3, 7, 5, 6, 0, 1]

# %%
seq[3:4] = [6, 3]

# %%
seq
# Out:
# [7, 2, 3, 6, 3, 5, 6, 0, 1]
